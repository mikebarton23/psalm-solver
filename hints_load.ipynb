# %%
import pandas as pd

# %%
df = pd.read_json('data/hints2.json')

# %%
df
# Out:
#           id                                             hint_1  \
# 0   42010020  This verse emphasizes the true cause of rejoic...
# 1   43006029   This verse defines the work God desires from us.
# 2   40012045  A warning about how a purified state can becom...
# 3   42005001  Describes a scene where Jesus is surrounded by...
# 4   41011033  Jesus responds to a challenge about His author...
# 5   46007003  A directive about marital duties and mutual re...
# 6   43011027  A profound confession of faith in Jesus' ident...
# 7   45004008        Talks about the blessedness of forgiveness.
# 8   45008010  Discusses the transformative power of Christ w...
# 9   41014058  Jesus' prophecy about destroying and raising t...
# 10  41014058  A statement about a structure's destruction an...
# 11  58012026  Reference to a voice causing seismic disturbance.
# 12  42012001  Description of a crowded gathering and a cauti...
# 13  43007006            A statement about timing and readiness.
# ...

# %%
df.to_csv("hint_export_2.csv", index=False)
